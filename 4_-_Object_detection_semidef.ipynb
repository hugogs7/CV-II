# %% [markdown]
# # Face detection
# In this notebook we will use an object detection network to detect faces in images. In this case, we will only need positive samples. The network will be fed with images that contain faces and the coordinates of their bounding boxes. The negative samples are implicitly the rest of the image patches without faces.
#
# Since the architecture and the training of an object detection network is quite complex, you are going to download and learn to use a You Look Only Once (YOLO) network. This notebook reproduces all the steps to build an object detection system from scratch.
#
# Global requirements:
# - git
#
# Python requirements:
# - matplotlib
# - pytorch
# - glob
# - opencv
# - shapely

# %% [markdown]
# ## The problem
# You have to develop a solution to detect faces in images and to identify if they are using a mask. To this end, you have a dataset of more than 800 annotated images. There are three classes in this dataset: without mask, with mask, and mask weared incorrect.

# %%
import matplotlib.pyplot as plt


im1 = plt.imread('res/facemask/images/train/maksssksksss230.png')
im2 = plt.imread('res/facemask/images/train/maksssksksss345.png')

fig, ax = plt.subplots(1,2)
ax[0].imshow(im1)
ax[0].axis('off')
ax[1].imshow(im2)
ax[1].axis('off')
plt.show()

# %% [markdown]
# The images are annotated in XML following the VOC format:
# ```
# <annotation>
#     <folder>images</folder>
#     <filename>maksssksksss345.png</filename>
#     <size>
#         <width>400</width>
#         <height>267</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#         <name>with_mask</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>186</xmin>
#             <ymin>110</ymin>
#             <xmax>218</xmax>
#             <ymax>142</ymax>
#         </bndbox>
#     </object>
#     <object>
#         <name>without_mask</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>148</xmin>
#             <ymin>109</ymin>
#             <xmax>182</xmax>
#             <ymax>136</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# The images for training are stored in the directory `res/facemask/images/train` and the images for validation, in `res/facemask/images/val`. The annotations are stored in the `res/facemask/labels/train` and `res/facemask/labels/val`. The name of the image and its corresponding annotation file is the same but the extension.

# %% [markdown]
# The following function reads a xml and returns a list with the coordinates of all the bounding boxes and their corresponding classes:

# %%
from xml.dom.minidom import parse
from matplotlib.patches import Rectangle
import numpy as np


FACE_MASK_CLASSES = {
    'with_mask': 0,
    'mask_weared_incorrect': 1,
    'without_mask': 2
}
COLORS = {
    0: 'green',
    1: 'purple',
    2: 'red',
}

def parse_xml_voc(filename):
    document = parse(filename)
    
    xmin = document.getElementsByTagName("xmin")
    ymin = document.getElementsByTagName("ymin")
    xmax = document.getElementsByTagName("xmax")
    ymax = document.getElementsByTagName("ymax")
    name = document.getElementsByTagName("name")

    data = np.zeros((len(xmin), 5)) # Label + 4 coordinates
    for idx in range(len(xmin)):
        data[idx, 0] = FACE_MASK_CLASSES[name[idx].firstChild.nodeValue]
        data[idx, 1] = int(xmin[idx].firstChild.nodeValue)
        data[idx, 2] = int(ymin[idx].firstChild.nodeValue)
        data[idx, 3] = int(xmax[idx].firstChild.nodeValue)
        data[idx, 4] = int(ymax[idx].firstChild.nodeValue)
    
    return data

data = parse_xml_voc('res/facemask/labels/train/maksssksksss345.xml')

plt.imshow(im2)
plt.axis('off')
for box in data:
    label = box[0]
    x1, y1, x2, y2 = box[1:]
    # Rectangle( (xmin, ymin), width, height, ...)
    plt.gca().add_patch(Rectangle((x1, y1), x2-x1, y2-y1, 
                              edgecolor=COLORS[label], 
                              facecolor='none',
                              lw=2))
plt.show()

# %% [markdown]
# ## Step 1: Prepare the environment
#
# You can execute command line instructions from the Jupyter environment. In this notebook, you are going to download the source code of the official YOLOv7 network from github and install its requirements.

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# fatal: destination path 'yolov7' already exists and is not an empty directory.

# %%
# !python3 -m pip install -r yolov7/requirements.txt
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 4)) (3.10.9)
# Requirement already satisfied: numpy<1.24.0,>=1.18.5 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 5)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 6)) (4.11.0.86)
# Requirement already satisfied: Pillow>=7.1.2 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 7)) (12.2.0)
# Requirement already satisfied: PyYAML>=5.3.1 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 9)) (2.34.2)
# Requirement already satisfied: scipy>=1.4.1 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 10)) (1.15.3)
# Requirement already satisfied: torch!=1.12.0,>=1.7.0 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 11)) (2.5.1+cu121)
# Requirement already satisfied: torchvision!=0.13.0,>=0.8.1 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 12)) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.41.0 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 13)) (4.67.3)
# Requirement already satisfied: protobuf<4.21.3 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 14)) (4.21.2)
# Requirement already satisfied: tensorboard>=2.4.1 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 17)) (2.20.0)
# Requirement already satisfied: pandas>=1.1.4 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 21)) (2.3.3)
# Requirement already satisfied: seaborn>=0.11.0 in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 22)) (0.13.2)
# Requirement already satisfied: ipython in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 34)) (8.39.0)
# Requirement already satisfied: psutil in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 35)) (7.2.2)
# Requirement already satisfied: thop in ./cv/lib/python3.10/site-packages (from -r yolov7/requirements.txt (line 36)) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in ./cv/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov7/requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./cv/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov7/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./cv/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov7/requirements.txt (line 4)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./cv/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov7/requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./cv/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov7/requirements.txt (line 4)) (26.2)
# Requirement already satisfied: pyparsing>=3 in ./cv/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov7/requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./cv/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov7/requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./cv/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov7/requirements.txt (line 9)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./cv/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov7/requirements.txt (line 9)) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in ./cv/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov7/requirements.txt (line 9)) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./cv/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov7/requirements.txt (line 9)) (2026.5.20)
# Requirement already satisfied: filelock in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (4.15.0)
# Requirement already satisfied: networkx in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (3.4.2)
# Requirement already satisfied: jinja2 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: fsspec in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in ./cv/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./cv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (12.9.86)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./cv/lib/python3.10/site-packages (from sympy==1.13.1->torch!=1.12.0,>=1.7.0->-r yolov7/requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in ./cv/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov7/requirements.txt (line 17)) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in ./cv/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov7/requirements.txt (line 17)) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in ./cv/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov7/requirements.txt (line 17)) (3.10.2)
# Requirement already satisfied: setuptools>=41.0.0 in ./cv/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov7/requirements.txt (line 17)) (82.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./cv/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov7/requirements.txt (line 17)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./cv/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov7/requirements.txt (line 17)) (3.1.8)
# Requirement already satisfied: pytz>=2020.1 in ./cv/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov7/requirements.txt (line 21)) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in ./cv/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov7/requirements.txt (line 21)) (2026.2)
# Requirement already satisfied: decorator in ./cv/lib/python3.10/site-packages (from ipython->-r yolov7/requirements.txt (line 34)) (5.3.1)
# Requirement already satisfied: exceptiongroup in ./cv/lib/python3.10/site-packages (from ipython->-r yolov7/requirements.txt (line 34)) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in ./cv/lib/python3.10/site-packages (from ipython->-r yolov7/requirements.txt (line 34)) (0.20.0)
# Requirement already satisfied: matplotlib-inline in ./cv/lib/python3.10/site-packages (from ipython->-r yolov7/requirements.txt (line 34)) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in ./cv/lib/python3.10/site-packages (from ipython->-r yolov7/requirements.txt (line 34)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./cv/lib/python3.10/site-packages (from ipython->-r yolov7/requirements.txt (line 34)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in ./cv/lib/python3.10/site-packages (from ipython->-r yolov7/requirements.txt (line 34)) (2.20.0)
# Requirement already satisfied: stack_data in ./cv/lib/python3.10/site-packages (from ipython->-r yolov7/requirements.txt (line 34)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./cv/lib/python3.10/site-packages (from ipython->-r yolov7/requirements.txt (line 34)) (5.15.0)
# Requirement already satisfied: wcwidth in ./cv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->-r yolov7/requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in ./cv/lib/python3.10/site-packages (from jedi>=0.16->ipython->-r yolov7/requirements.txt (line 34)) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in ./cv/lib/python3.10/site-packages (from pexpect>4.3->ipython->-r yolov7/requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./cv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->-r yolov7/requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: markupsafe>=2.1.1 in ./cv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r yolov7/requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: executing>=1.2.0 in ./cv/lib/python3.10/site-packages (from stack_data->ipython->-r yolov7/requirements.txt (line 34)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./cv/lib/python3.10/site-packages (from stack_data->ipython->-r yolov7/requirements.txt (line 34)) (3.0.1)
# Requirement already satisfied: pure-eval in ./cv/lib/python3.10/site-packages (from stack_data->ipython->-r yolov7/requirements.txt (line 34)) (0.2.3)

# %%
import sys
import torch
import numpy as np
import cv2

print("Python:", sys.executable)
print("Python version:", sys.version)
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
print("NumPy:", np.__version__)
print("OpenCV:", cv2.__version__)
# Out:
# Python: /home/hugo/CVII/cv/bin/python
# Python version: 3.10.12 (main, Mar  3 2026, 11:56:32) [GCC 11.4.0]
# Torch: 2.5.1+cu121
# CUDA available: True
# GPU: NVIDIA GeForce GTX 1650
# NumPy: 1.23.5
# OpenCV: 4.11.0

# %% [markdown]
# ## Step 2: Prepare the dataset
# For each sample, the YOLO network receives a pair of files: the image and its corresponding annotations in a txt file. The name of the image and the txt file should be the same. Each line in the txt file contains the annotation of a region following this format:
# ```
# label xc yc w h
# ````
# where `xc` and `yc` are the coordinates of the center of a bounding box and `w`and  `h` are its width and height. These four values are relative to size of the image. For example, if the size of the image is 1000x1000 and the center of a bounding box is at (500,500), the relative values are (0.5, 0.5).
#
# ### Exercise
# Write a function to convert a file from the VOC format to the YOLO format and write it in a specific directory.

# %% [markdown]
# **Exercise — VOC to YOLO conversion:** I read each bounding box from the VOC XML (absolute pixel coordinates `xmin, ymin, xmax, ymax`), obtain the image dimensions via `plt.imread`, compute the normalised center coordinates and dimensions required by YOLO (`xc, yc, w, h` ∈ [0,1]), and write every annotation line as `label xc yc w h` to the output txt file.

# %%
import csv

def voc_to_yolo(in_image, in_annotations, out_annotations):
    document = parse(in_annotations)
    
    xmin = document.getElementsByTagName("xmin")
    ymin = document.getElementsByTagName("ymin")
    xmax = document.getElementsByTagName("xmax")
    ymax = document.getElementsByTagName("ymax")
    name = document.getElementsByTagName("name")

    f = open(out_annotations, 'w')
    writer = csv.writer(f, delimiter=' ')
    
    img = plt.imread(in_image)
    img_h, img_w = img.shape[:2]  # Get image dimensions for normalization
    
    for idx in range(len(xmin)):
        # Get class label
        label = FACE_MASK_CLASSES[name[idx].firstChild.nodeValue]
        
        # Read absolute pixel coordinates from VOC format
        x1 = int(xmin[idx].firstChild.nodeValue)
        y1 = int(ymin[idx].firstChild.nodeValue)
        x2 = int(xmax[idx].firstChild.nodeValue)
        y2 = int(ymax[idx].firstChild.nodeValue)
        
        # Convert to YOLO format: center coords + width/height, all normalized to [0,1]
        xc = ((x1 + x2) / 2) / img_w
        yc = ((y1 + y2) / 2) / img_h
        w  = (x2 - x1) / img_w
        h  = (y2 - y1) / img_h
        
        writer.writerow([label, xc, yc, w, h])
    f.close()

voc_to_yolo('res/facemask/images/train/maksssksksss345.png','res/facemask/labels/train/maksssksksss345.xml','res/facemask/labels/train/maksssksksss345.txt')

# %% [markdown]
# Check the contents of the file (only works in linux/osx):

# %%
# %cat res/facemask/labels/train/maksssksksss345.txt
# Out:
# 0 0.505 0.47191011235955055 0.08 0.1198501872659176
# 2 0.4125 0.45880149812734083 0.085 0.10112359550561797

# %% [markdown]
# ### Exercise
#
# Transform all the xml in the validation and train datasets into YOLO format. Store the txt files in the same directories as the xml files (`res/facemask/labels/train` or `res/facemask/labels/val`).
#
# *Hint*: in previous notebooks we have used the library `glob` for reading files from a directory.

# %% [markdown]
# **Exercise — Batch conversion:** I use `glob` to collect every `.xml` file in both `train` and `val` label directories, derive the matching image path by swapping `labels` → `images` and the extension to `.png`, and call the previously defined `voc_to_yolo` function for each pair.

# %%
import glob
import os

# Iterate over both splits and convert every XML annotation to YOLO txt format
for split in ['train', 'val']:
    xml_files = glob.glob(f'res/facemask/labels/{split}/*.xml')
    for xml_file in xml_files:
        base = os.path.splitext(xml_file)[0]          # path without extension
        # Corresponding image is in the 'images' subtree with .png extension
        img_file = base.replace('labels', 'images') + '.png'
        out_txt  = base + '.txt'
        voc_to_yolo(img_file, xml_file, out_txt)

print('Conversion complete.')
# Out:
# Conversion complete.

# %% [markdown]
# Check the creation of files (only works in linux/osx):

# %%
# !echo "Number of xml files:"
# %ls res/facemask/labels/*/*.xml |wc -l
# !echo "Number of txt files:"
# %ls res/facemask/labels/*/*.txt |wc -l
# Out:
# Number of xml files:
# 853
# Number of txt files:
# 853

# %% [markdown]
# ## Step 2: Set up training
#
# You will not need to write any code to train a YOLO network. Instead, you will use a predefined architecture and tweak it to fit your problem.
#
# This step requires that you copy and edit some files in your filesystem using a text editor outside the Jupyter environment.
#
# ### Exercise
# Follow the next steps to set up the training stage:
#
# 1. Create a file `res/facemask/facemask.yaml` where you will define the absolute path to your files  and the features of your dataset as follows:
#
# ```
# train: /absolute/path/to/res/facemask/images/train
# val: /absolute/path/to/res/facemask/images/val
#
# nc: 3
# names: ['with mask', 'mask weared incorrect', 'without mask']
# ```
# **Important**: the training will not work unless you write in this file the **actual absolute path** to your files.
#
# 2. Define the architecture of your network and adapt it to the number of classes of this problem. Copy the file `yolov7/cfg/training/yolov7.yaml`to  `res/facemask/yolov7_facemask.yaml` and edit the number of classes (3 instead of 80).
#
# Run the following lines to check the files (only works in linux/osx).

# %% [markdown]
# **Exercise — Dataset & architecture YAML setup:**
#
# I need to create two configuration files outside this notebook (using a text editor or the terminal):
#
# 1. **`res/facemask/facemask.yaml`** — dataset config with the absolute paths to the train/val image folders and the 3 class names.
# 2. **`res/facemask/yolov7_facemask.yaml`** — architecture config copied from `yolov7/cfg/training/yolov7.yaml` with `nc` changed from `80` to `3`.
#
# **WSL example commands:**
# ```bash
# # 1. Get the absolute path to the project root
# pwd
#
# # 2. Create facemask.yaml  (replace /absolute/path accordingly)
# cat > res/facemask/facemask.yaml << 'EOF'
# train: /absolute/path/to/res/facemask/images/train
# val:   /absolute/path/to/res/facemask/images/val
# nc: 3
# names: ['with_mask', 'mask_weared_incorrect', 'without_mask']
# EOF
#
# # 3. Copy and patch the architecture file
# cp yolov7/cfg/training/yolov7.yaml res/facemask/yolov7_facemask.yaml
# sed -i 's/^nc: 80/nc: 3/' res/facemask/yolov7_facemask.yaml
# ```

# %%
# %cd ..
# Out:
# /home/hugo/CVII

# %%
# !echo "Checking files:\n\n=== facemask.yaml ===\n"
# %cat res/facemask/facemask.yaml
# Out:
# Checking files:\n\n=== facemask.yaml ===\n
# train: /home/hugo/CVII/res/facemask/images/train
# val: /home/hugo/CVII/res/facemask/images/val
# nc: 3
# names: ['with_mask', 'mask_weared_incorrect', 'without_mask']

# %%
# !echo "=== yolov7_facemask.yaml ===\n"
# !head -n 10 res/facemask/yolov7_facemask.yaml
# Out:
# === yolov7_facemask.yaml ===\n
# # parameters
# nc: 3  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [12,16, 19,36, 40,28]  # P3/8
#   - [36,75, 76,55, 72,146]  # P4/16
#   - [142,110, 192,243, 459,401]  # P5/32

# %% [markdown]
# ## Step 3: Train the network
#
# Once both the architecture and dataset were defined, you can train the YOLO network. To this end, you are going to use the script `yolov7/train.py` and the weights of a pretrained network (`res/facemask/yolov7_weights.pt`).
#
# ### Exercise
# Run the following command to train the YOLO network that you have configured for 3 epochs.
#
# **Important**: check that all the files are stored in the appropriate paths.
#
# **Note**: the training can last several minutes (even hours) if it is run on a CPU.
#
# The results of the training (info, graphs, weights, ...)  will be stored in the directory `runs/trainings/facemask??` where `??` is a number.

# %%
# %cd yolov7
# !python3 train.py --img-size 640 --cfg ../res/facemask/yolov7_facemask.yaml --hyp data/hyp.scratch.custom.yaml --batch 8 --epochs 3 --data ../res/facemask/facemask.yaml --weights ../res/facemask/yolov7_weights.pt --workers 8 --name facemask
# Out:
# /home/hugo/CVII/yolov7
# YOLOR 🚀 v0.1-128-ga207844 torch 2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4095.6875MB)
#
# Namespace(weights='../res/facemask/yolov7_weights.pt', cfg='../res/facemask/yolov7_facemask.yaml', data='../res/facemask/facemask.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=3, batch_size=8, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='facemask', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/facemask2', total_batch_size=8)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.2, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, paste_in=0.0, loss_ota=1
# /home/hugo/CVII/yolov7/train.py:71: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   run_id = torch.load(weights, map_location=device).get('wandb_id') if weights.endswith('.pt') and os.path.isfile(weights) else None
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# /home/hugo/CVII/yolov7/train.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(weights, map_location=device)  # load checkpoint
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1     44944  models.yolo.IDetect                     [3, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# /home/hugo/CVII/cv/lib/python3.10/site-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 415 layers, 37207344 parameters, 37207344 gradients, 105.1 GFLOPS
#
# Transferred 564/566 items from ../res/facemask/yolov7_weights.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 95 .bias, 95 conv.weight, 98 other
# train: Scanning '/home/hugo/CVII/res/facemask/labels/train' images and labels...
# train: New cache created: /home/hugo/CVII/res/facemask/labels/train.cache
# val: Scanning '/home/hugo/CVII/res/facemask/labels/val' images and labels... 153
# val: New cache created: /home/hugo/CVII/res/facemask/labels/val.cache
#
# autoanchor: Analyzing anchors... anchors/target = 5.30, Best Possible Recall (BPR) = 0.9988
# /home/hugo/CVII/yolov7/train.py:299: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler(enabled=cuda)
# Image sizes 640 train, 640 test
# Using 4 dataloader workers
# Logging results to runs/train/facemask2
# Starting training for 3 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#   0%|                                                    | 0/88 [00:00<?, ?it/s]/home/hugo/CVII/yolov7/train.py:360: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=cuda):
#        0/2     6.55G       nan       nan       nan       nan       194       640libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        0/2     6.55G       nan       nan       nan       nan       124       640libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        0/2     6.55G       nan       nan       nan       nan        77       640^C
# Process Process-6:
# Process Process-3:
# Process Process-7:
# Process Process-4:
# Process Process-8:
# Process Process-5:
# Process Process-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 360, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/usr/lib/python3.10/shutil.py", line 724, in rmtree
#     if os.path.samestat(orig_st, os.fstat(fd)):
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 334, in _exit_function
#     _run_finalizers(0)
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 209, in _finalize_close
#     notempty.notify()
#   File "/usr/lib/python3.10/threading.py", line 359, in notify
#     def notify(self, n=1):
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 332, in _exit_function
#     info('process shutting down')
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 52, in info
#     def info(msg, *args):
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 334, in _exit_function
#     _run_finalizers(0)
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 360, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 199, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.10/threading.py", line 1096, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 360, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 199, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.10/threading.py", line 1090, in join
#     if not self._started.is_set():
# KeyboardInterrupt

# %%
import glob, numpy as np

errors = []
for txt in glob.glob('../res/facemask/labels/**/*.txt', recursive=True):
    data = np.loadtxt(txt)
    if data.ndim == 1:
        data = data[np.newaxis,:]
    if np.any(data[:,1:] < 0) or np.any(data[:,1:] > 1):
        errors.append(txt)

print(f"Archivos con valores fuera de rango: {len(errors)}")
for e in errors[:5]:
    print(e)
# Out:
# Archivos con valores fuera de rango: 0

# %%
# %%bash
# # Create a tiny dataset with just 10 images
# mkdir -p /tmp/toy/images/train /tmp/toy/images/val
# mkdir -p /tmp/toy/labels/train /tmp/toy/labels/val
#
# # Copy 10 train images and their labels
# ls /home/hugo/CVII/res/facemask/images/train/*.png | head -10 | xargs -I{} cp {} /tmp/toy/images/train/
# ls /home/hugo/CVII/res/facemask/images/val/*.png   | head -5  | xargs -I{} cp {} /tmp/toy/images/val/
#
# for f in /tmp/toy/images/train/*.png; do
#     base=$(basename $f .png)
#     cp /home/hugo/CVII/res/facemask/labels/train/$base.txt /tmp/toy/labels/train/
# done
# for f in /tmp/toy/images/val/*.png; do
#     base=$(basename $f .png)
#     cp /home/hugo/CVII/res/facemask/labels/val/$base.txt /tmp/toy/labels/val/
# done
#
# # Create toy yaml
# cat > /tmp/toy/toy.yaml << 'EOF'
# train: /tmp/toy/images/train
# val: /tmp/toy/images/val
# nc: 3
# names: ['with_mask', 'mask_weared_incorrect', 'without_mask']
# EOF
#
# echo "Dataset ready"
# Out:
# Dataset ready

# %%
# !python3 train.py --img-size 320 --cfg ../res/facemask/yolov7_facemask.yaml \
    --hyp data/hyp.scratch.custom.yaml --batch 4 --epochs 1 \
    --data /tmp/toy/toy.yaml \
    --weights ../res/facemask/yolov7_weights.pt \
    --workers 2 --name toy_test
# Out:
# YOLOR 🚀 v0.1-128-ga207844 torch 2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4095.6875MB)
#
# Namespace(weights='../res/facemask/yolov7_weights.pt', cfg='../res/facemask/yolov7_facemask.yaml', data='/tmp/toy/toy.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=1, batch_size=4, img_size=[320, 320], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=2, project='runs/train', entity=None, name='toy_test', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/toy_test', total_batch_size=4)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.2, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, paste_in=0.0, loss_ota=1
# /home/hugo/CVII/yolov7/train.py:71: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   run_id = torch.load(weights, map_location=device).get('wandb_id') if weights.endswith('.pt') and os.path.isfile(weights) else None
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# /home/hugo/CVII/yolov7/train.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(weights, map_location=device)  # load checkpoint
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1     44944  models.yolo.IDetect                     [3, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# /home/hugo/CVII/cv/lib/python3.10/site-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 415 layers, 37207344 parameters, 37207344 gradients, 105.1 GFLOPS
#
# Transferred 564/566 items from ../res/facemask/yolov7_weights.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 95 .bias, 95 conv.weight, 98 other
# train: Scanning '/tmp/toy/labels/train' images and labels... 10 found, 0 missing
# train: New cache created: /tmp/toy/labels/train.cache
# val: Scanning '/tmp/toy/labels/val' images and labels... 5 found, 0 missing, 0 e
# val: New cache created: /tmp/toy/labels/val.cache
#
# autoanchor: Analyzing anchors... anchors/target = 4.82, Best Possible Recall (BPR) = 1.0000
# /home/hugo/CVII/yolov7/train.py:299: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler(enabled=cuda)
# Image sizes 320 train, 320 test
# Using 2 dataloader workers
# Logging results to runs/train/toy_test
# Starting training for 1 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#   0%|                                                     | 0/3 [00:00<?, ?it/s]/home/hugo/CVII/yolov7/train.py:360: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=cuda):
#        0/0     0.57G       nan       nan       nan       nan         9       320
# /home/hugo/CVII/cv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
#                Class      Images      Labels           P           R      mAP@.5
#                  all           5           0           0           0           0           0
# /home/hugo/CVII/cv/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/hugo/CVII/cv/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# 1 epochs completed in 0.011 hours.
#
# /home/hugo/CVII/yolov7/utils/general.py:802: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   x = torch.load(f, map_location=torch.device('cpu'))
# Optimizer stripped from runs/train/toy_test/weights/last.pt, 74.8MB
# Optimizer stripped from runs/train/toy_test/weights/best.pt, 74.8MB

# %%
# %%bash
# cp /home/hugo/CVII/yolov7/data/hyp.scratch.custom.yaml /home/hugo/CVII/yolov7/data/hyp.facemask.yaml
# sed -i 's/warmup_epochs: 3.0/warmup_epochs: 1.0/' /home/hugo/CVII/yolov7/data/hyp.facemask.yaml
# grep warmup_epochs /home/hugo/CVII/yolov7/data/hyp.facemask.yaml  # verificar
# Out:
# warmup_epochs: 1.0  # warmup epochs (fractions ok)

# %%
# !python3 train.py --img-size 416 --cfg ../res/facemask/yolov7_facemask.yaml \
    --hyp data/hyp.facemask.yaml --batch 4 --epochs 3 \
    --data ../res/facemask/facemask.yaml \
    --weights ../res/facemask/yolov7_weights.pt \
    --workers 4 --name facemask
# Out:
# YOLOR 🚀 v0.1-128-ga207844 torch 2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4095.6875MB)
#
# Namespace(weights='../res/facemask/yolov7_weights.pt', cfg='../res/facemask/yolov7_facemask.yaml', data='../res/facemask/facemask.yaml', hyp='data/hyp.facemask.yaml', epochs=3, batch_size=4, img_size=[416, 416], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=4, project='runs/train', entity=None, name='facemask', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/facemask3', total_batch_size=4)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=1.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.2, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, paste_in=0.0, loss_ota=1
# /home/hugo/CVII/yolov7/train.py:71: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   run_id = torch.load(weights, map_location=device).get('wandb_id') if weights.endswith('.pt') and os.path.isfile(weights) else None
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# /home/hugo/CVII/yolov7/train.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(weights, map_location=device)  # load checkpoint
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1     44944  models.yolo.IDetect                     [3, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# /home/hugo/CVII/cv/lib/python3.10/site-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 415 layers, 37207344 parameters, 37207344 gradients, 105.1 GFLOPS
#
# Transferred 564/566 items from ../res/facemask/yolov7_weights.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 95 .bias, 95 conv.weight, 98 other
# /home/hugo/CVII/yolov7/utils/datasets.py:392: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   cache, exists = torch.load(cache_path), True  # load
# train: Scanning '/home/hugo/CVII/res/facemask/labels/train.cache' images and lab
# val: Scanning '/home/hugo/CVII/res/facemask/labels/val.cache' images and labels.
#
# autoanchor: Analyzing anchors... anchors/target = 4.48, Best Possible Recall (BPR) = 0.9974
# /home/hugo/CVII/yolov7/train.py:299: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler(enabled=cuda)
# Image sizes 416 train, 416 test
# Using 4 dataloader workers
# Logging results to runs/train/facemask3
# Starting training for 3 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#   0%|                                                   | 0/175 [00:00<?, ?it/s]/home/hugo/CVII/yolov7/train.py:360: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=cuda):
#        0/2      1.8G   0.01458  0.006965 0.0004616   0.02201        14       416libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        0/2      1.8G   0.01439  0.006658 0.0004534    0.0215        17       416libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        0/2     1.83G   0.01408  0.006023 0.0004629   0.02057        28       416libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        0/2     1.83G   0.01417  0.006136 0.0004527   0.02076        29       416
#                Class      Images      Labels           P           R      mAP@.5
#                  all         153         650       0.835       0.438       0.452       0.319
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#        1/2     1.84G    0.0131  0.005457  0.000518   0.01908        17       416libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        1/2     1.84G   0.01325  0.005284 0.0004264   0.01896        31       416libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        1/2     1.84G   0.01319  0.005196 0.0004106    0.0188        28       416libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        1/2     1.84G   0.01328  0.005185 0.0004543   0.01891        24       416
#                Class      Images      Labels           P           R      mAP@.5
#                  all         153         650         0.9        0.43       0.449       0.319
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#        2/2     2.33G   0.01242  0.004572 0.0002821   0.01727        24       416libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        2/2     2.33G   0.01317  0.004905 0.0003177   0.01839        18       416libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        2/2     2.33G   0.01317  0.004939 0.0003014   0.01841        42       416libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#        2/2     2.33G   0.01321  0.004932 0.0003382   0.01848        26       416
#                Class      Images      Labels           P           R      mAP@.5
#                  all         153         650       0.809       0.454       0.455       0.321
#            with_mask         153         533       0.919       0.424       0.438       0.307
# mask_weared_incorrect         153          21        0.75       0.429       0.432       0.333
#         without_mask         153          96       0.757        0.51       0.496       0.324
# 3 epochs completed in 0.216 hours.
#
# /home/hugo/CVII/yolov7/utils/general.py:802: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   x = torch.load(f, map_location=torch.device('cpu'))
# Optimizer stripped from runs/train/facemask3/weights/last.pt, 74.8MB
# Optimizer stripped from runs/train/facemask3/weights/best.pt, 74.8MB

# %% [markdown]
# ## Step 4: Check the results
#
# Once the training is finished, you can process a new image to detect faces with or without masks. The following function gets the predictions of a YOLO network on an input image.

# %%
import time
import torch
import cv2
import skimage.transform
from utils.torch_utils import select_device
from utils.datasets import letterbox
from models.experimental import attempt_load


def get_predictions(device, weights, image_paths, imgsz=640):
    
    model = attempt_load(weights, map_location=device)
    stride = int(model.stride.max())
    half = device.type != 'cpu' 
    if half:
        model.half()
    
    image_predictions = []
    for path in image_paths:
        img = plt.imread(path)
        if img.shape[2] > 3:
            img = img[:,:,:3]
        # Resize image and add suitable paddings
        img = letterbox(img, (imgsz, imgsz), stride=stride)[0] 
        img = np.ascontiguousarray(img.transpose(2,0,1))
        img = torch.from_numpy(img).to(device)
        img = torch.unsqueeze(img, 0)
        img = img.half() if half else img.float()  # uint8 to fp16/32
        t1 = time.time()
        with torch.no_grad(): 
            model_predictions = model(img,augment=True)[0]
        t2 = time.time()
        # predictions format: [xc, yc, w, h, object confidence, confidences of each class]        
        predictions = model_predictions[0].detach().cpu().numpy()
        print(f"Detection in {t2-t1}s")
        image_predictions.append(predictions)
    return image_predictions

        
        
    
if torch.cuda.is_available():
    device = select_device("")
else:
    device = select_device("cpu")

image_paths = ['../res/facemask/images/val//maksssksksss788.png', 
               '../res/facemask/images/val/maksssksksss792.png']
image_predictions = get_predictions(device, 'runs/train/facemask3/weights/best.pt', image_paths)
# Out:
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Detection in 0.48050856590270996s
# Detection in 0.3887295722961426s

# %% [markdown]
# ### Exercise
# Implement a function to detect faces in an image given the predictions computed by the network. Compute the confidence of a region as the product of the object confidence and the class confidence and use a threshold to discard regions with a low score. If two or more regions overlap, take the region with the highest score only.
#
# *Hint*: the library `shapely` provides functions to compute the intersection between two boxes, e.g.:

# %%
from shapely.geometry import box
#          x1,y1,x2,y2
box1 = box(0, 0, 10, 10)
box2 = box(5, 5, 10, 10)
box3 = box(11, 11, 20, 20)

print(f"Box1-Box2 intersected = {box1.intersects(box2)} | Intersection area: {box1.intersection(box2).area} | IoU: {box1.intersection(box2).area/box1.union(box2).area}")
print(f"Box1-Box3 intersected = {box1.intersects(box3)} | Intersection area: {box1.intersection(box3).area} | IoU: {box1.intersection(box3).area/box1.union(box3).area}")
# Out:
# Box1-Box2 intersected = True | Intersection area: 25.0 | IoU: 0.25
# Box1-Box3 intersected = False | Intersection area: 0.0 | IoU: 0.0

# %% [markdown]
# **Exercise — Face detection with NMS:** I iterate over all raw YOLO predictions, compute each region's confidence as `obj_conf × class_conf[best_class]`, and discard any region below the threshold. I then apply greedy Non-Maximum Suppression (NMS): I sort surviving candidates by score, pick the highest-scoring box, and suppress all remaining candidates whose IoU with it is ≥ 0.5. The output is an `(N, 6)` array with columns `[x1, y1, x2, y2, score, label]`.

# %%
# %matplotlib inline

import math
import matplotlib.pyplot as plt
from shapely.geometry import box


def detect_faces(predictions, imgsz=640, threshold=0.9):
    candidates = []
    for pred in predictions:
        if any(math.isnan(v) for v in pred):
            continue
            
        xc, yc, w_box, h_box = pred[0], pred[1], pred[2], pred[3]
        obj_conf   = pred[4]
        class_conf = pred[5:]
        
        label = int(np.argmax(class_conf))
        score = float(obj_conf) * float(class_conf[label])
        
        if score < threshold:
            continue
        
        x1 = xc - w_box / 2
        y1 = yc - h_box / 2
        x2 = xc + w_box / 2
        y2 = yc + h_box / 2
        
        if x1 >= x2 or y1 >= y2:
            continue
        if any(math.isnan(v) for v in [x1, y1, x2, y2]):
            continue
            
        candidates.append([x1, y1, x2, y2, score, label])
    
    if len(candidates) == 0:
        return np.zeros((0, 6))
    
    candidates.sort(key=lambda r: r[4], reverse=True)
    
    kept = []
    while candidates:
        best = candidates.pop(0)
        kept.append(best)
        b_best = box(best[0], best[1], best[2], best[3])
        survivors = []
        for cand in candidates:
            b_cand = box(cand[0], cand[1], cand[2], cand[3])
            if b_best.intersects(b_cand):
                iou = b_best.intersection(b_cand).area / b_best.union(b_cand).area
                if iou < 0.5:
                    survivors.append(cand)
            else:
                survivors.append(cand)
        candidates = survivors
    
    return np.array(kept)
        

for image_path, predictions in zip(image_paths, image_predictions):
    faces = detect_faces(predictions)

    img = plt.imread(image_path)
    # Convert PNG float [0,1] → uint8 [0,255] before letterbox
    if img.max() <= 1.0:
        img = (img * 255).astype(np.uint8)
    # Drop alpha channel if present
    if img.ndim == 3 and img.shape[2] == 4:
        img = img[:, :, :3]
    img = letterbox(img, (640, 640))[0]
    img = np.clip(img, 0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.axis('off')
    for x1, y1, x2, y2, score, label in faces:
        plt.gca().add_patch(Rectangle((x1, y1), x2-x1, y2-y1, 
                            edgecolor=COLORS[int(label)], 
                            facecolor='none',
                            lw=2))
    plt.show()

# %%
# !ls runs/train/
# Out:
# facemask  facemask2  facemask3	toy_test
